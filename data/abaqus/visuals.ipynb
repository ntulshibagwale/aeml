# %%
import pandas as pd
data = pd.read_csv("2in.csv")
time_2in = data['time'] * 10**6 # microseconds
side_upper_1_2in = data['side_upper_sensor_1']
side_mid_1_2in = data['side_mid_sensor_1']
top_1_2in = data['top_sensor_1']
top_edge_1_2in = data['top_edge_sensor_1']
side_upper_2_2in = data['side_upper_sensor_2']
side_mid_2_2in = data['side_mid_sensor_2']
top_2_2in = data['top_sensor_2']
top_edge_2_2in = data['top_edge_sensor_2']

# %%
data= pd.read_csv("8in.csv")
time_8in = data['time'] * 10**6 # microseconds
side_upper_1_8in = data['side_upper_sensor_1']
side_mid_1_8in = data['side_mid_sensor_1']
top_1_8in = data['top_sensor_1']
top_edge_1_8in = data['top_edge_sensor_1']
side_upper_2_8in = data['side_upper_sensor_2']
side_mid_2_8in = data['side_mid_sensor_2']
top_2_8in = data['top_sensor_2']
top_edge_2_8in = data['top_edge_sensor_2']

# %%
from ae_functions import create_figure
import ae_measure2
import matplotlib.pyplot as plt

# %% [markdown]
# ## Plot FEA Waveforms Sensor 1 and 2 for Each Plate Length

# %% [markdown]
# ### 2 in

# %%
# Side Upper - 2in
fig,spec2 = create_figure('2in',columns=1,rows=1,width=15,height=8,default_font_size=18\
                         ,tick_font_size=25,legend_font_size=18,axes_font_size=28,
                         title_font_size=28)
ax = fig.add_subplot(spec2[0,0])
ax.plot(time_2in,side_upper_1_2in,label = 'Side Upper 1', color='blue')
ax.plot(time_2in,side_upper_2_2in,label = 'Side Upper 2', color='red')
ax.set_xlabel('Time ($\mu$s)')
ax.set_ylabel('Displacement (m)')
ax.set_xlim([0,150])
#ax.set_ylim([-1.2e-8,1e-8])
ax.legend()
plt.show()

# Top - 2in
fig,spec2 = create_figure('2in',columns=1,rows=1,width=15,height=8,default_font_size=18\
                         ,tick_font_size=25,legend_font_size=18,axes_font_size=28,
                         title_font_size=28)
ax = fig.add_subplot(spec2[0,0])
ax.plot(time_2in,top_1_2in,label = 'Top 1', color='blue')
ax.plot(time_2in,top_2_2in,label = 'Top 2', color='red')
ax.set_xlabel('Time ($\mu$s)')
ax.set_ylabel('Displacement (m)')
ax.set_xlim([0,200])
ax.set_ylim([-1e-7,1.5e-7])
ax.legend()
plt.show()

# Top Edge - 2in
fig,spec2 = create_figure('2in',columns=1,rows=1,width=15,height=8,default_font_size=18\
                         ,tick_font_size=25,legend_font_size=18,axes_font_size=28,
                         title_font_size=28)
ax = fig.add_subplot(spec2[0,0])
ax.plot(time_2in,top_edge_1_2in,'-',label = 'Top Edge 1', color='blue')
ax.plot(time_2in,top_edge_2_2in,'-',label = 'Top Edge 2', color='red')
ax.set_xlabel('Time ($\mu$s)')
ax.set_ylabel('Displacement (m)')
ax.set_xlim([0,150])
#ax.set_ylim([-0.3e-7,0.2e-7])
ax.legend()
plt.show()

# Side Mid - 2in
fig,spec2 = create_figure('2in',columns=1,rows=1,width=15,height=8,default_font_size=18\
                         ,tick_font_size=25,legend_font_size=18,axes_font_size=28,
                         title_font_size=28)
ax = fig.add_subplot(spec2[0,0])
ax.plot(time_2in,side_mid_1_2in,'-',label = 'Side Mid 1', color='blue')
ax.plot(time_2in,side_mid_2_2in,'-',label = 'Side Mid 2', color='red')
ax.set_xlabel('Time ($\mu$s)')
ax.set_ylabel('Displacement (m)')
ax.set_xlim([0,150])
#ax.set_ylim([-0.3e-7,0.2e-7])
ax.legend()
plt.show()

# %% [markdown]
# ### 8 in

# %%
# Side Upper - 8in
fig,spec2 = create_figure('8in',columns=1,rows=1,width=15,height=8,default_font_size=18\
                         ,tick_font_size=25,legend_font_size=18,axes_font_size=28,
                         title_font_size=28)
ax = fig.add_subplot(spec2[0,0])
ax.plot(time_8in,side_upper_1_8in,label = 'Side Upper 1', color='blue')
ax.plot(time_8in,side_upper_2_8in,label = 'Side Upper 2', color='red')
ax.set_xlabel('Time ($\mu$s)')
ax.set_ylabel('Displacement (m)')
ax.set_xlim([0,150])
#ax.set_ylim([-1.2e-8,1e-8])
ax.legend()
plt.show()

# Top - 8in
fig,spec2 = create_figure('8in',columns=1,rows=1,width=15,height=8,default_font_size=18\
                         ,tick_font_size=25,legend_font_size=18,axes_font_size=28,
                         title_font_size=28)
ax = fig.add_subplot(spec2[0,0])
ax.plot(time_8in,top_1_8in,label = 'Top 1', color='blue')
ax.plot(time_8in,top_2_8in,label = 'Top 2', color='red')
ax.set_xlabel('Time ($\mu$s)')
ax.set_ylabel('Displacement (m)')
ax.set_xlim([0,200])
ax.set_ylim([-1e-7,1.5e-7])
ax.legend()
plt.show()

# Top Edge - 8in
fig,spec2 = create_figure('8in',columns=1,rows=1,width=15,height=8,default_font_size=18\
                         ,tick_font_size=25,legend_font_size=18,axes_font_size=28,
                         title_font_size=28)
ax = fig.add_subplot(spec2[0,0])
ax.plot(time_8in,top_edge_1_8in,'-',label = 'Top Edge 1', color='blue')
ax.plot(time_8in,top_edge_2_8in,'-',label = 'Top Edge 2', color='red')
ax.set_xlabel('Time ($\mu$s)')
ax.set_ylabel('Displacement (m)')
ax.set_xlim([0,150])
#ax.set_ylim([-0.3e-7,0.2e-7])
ax.legend()
plt.show()

# Side Mid - 8in
fig,spec2 = create_figure('8in',columns=1,rows=1,width=15,height=8,default_font_size=18\
                         ,tick_font_size=25,legend_font_size=18,axes_font_size=28,
                         title_font_size=28)
ax = fig.add_subplot(spec2[0,0])
ax.plot(time_8in,side_mid_1_8in,'-',label = 'Side Mid 1', color='blue')
ax.plot(time_8in,side_mid_2_8in,'-',label = 'Side Mid 2', color='red')
ax.set_xlabel('Time ($\mu$s)')
ax.set_ylabel('Displacement (m)')
ax.set_xlim([0,150])
#ax.set_ylim([-0.3e-7,0.2e-7])
ax.legend()
plt.show()

# %% [markdown]
# ## Plot Waveforms from All Plate Lengths

# %%
# Side Upper
fig,spec2 = create_figure('Side Upper',columns=1,rows=1,width=15,height=8,default_font_size=18\
                         ,tick_font_size=25,legend_font_size=18,axes_font_size=28,
                         title_font_size=28)
ax = fig.add_subplot(spec2[0,0])
ax.plot(time_2in,side_upper_1_2in,label = '2in - 1', color='blue')
ax.plot(time_8in,side_upper_1_8in,label = '8in - 1', color='red')
ax.set_xlabel('Time ($\mu$s)')
ax.set_ylabel('Displacement (m)')
ax.set_xlim([0,150])
#ax.set_ylim([-1.2e-8,1e-8])
ax.legend()
plt.show()

# Top - 8in
fig,spec2 = create_figure('Top',columns=1,rows=1,width=15,height=8,default_font_size=18\
                         ,tick_font_size=25,legend_font_size=18,axes_font_size=28,
                         title_font_size=28)
ax = fig.add_subplot(spec2[0,0])
ax.plot(time_2in,top_1_2in,label = '2in - 1', color='blue')
ax.plot(time_8in,top_1_8in,label = '8in - 1', color='red')
ax.set_xlabel('Time ($\mu$s)')
ax.set_ylabel('Displacement (m)')
ax.set_xlim([0,150])
#ax.set_ylim([-1.2e-8,1e-8])
ax.legend()
plt.show()

# Top Edge - 8in
fig,spec2 = create_figure('Top Edge',columns=1,rows=1,width=15,height=8,default_font_size=18\
                         ,tick_font_size=25,legend_font_size=18,axes_font_size=28,
                         title_font_size=28)
ax = fig.add_subplot(spec2[0,0])
ax.plot(time_2in,top_edge_1_2in,label = '2in - 1', color='blue')
ax.plot(time_8in,top_edge_1_8in,label = '8in - 1', color='red')
ax.set_xlabel('Time ($\mu$s)')
ax.set_ylabel('Displacement (m)')
ax.set_xlim([0,150])
#ax.set_ylim([-1.2e-8,1e-8])
ax.legend()
plt.show()

# Side Mid - 8in
fig,spec2 = create_figure('Side Mid',columns=1,rows=1,width=15,height=8,default_font_size=18\
                         ,tick_font_size=25,legend_font_size=18,axes_font_size=28,
                         title_font_size=28)
ax = fig.add_subplot(spec2[0,0])
ax.plot(time_2in,side_mid_1_2in,label = '2in - 1', color='blue')
ax.plot(time_8in,side_mid_1_8in,label = '8in - 1', color='red')
ax.set_xlabel('Time ($\mu$s)')
ax.set_ylabel('Displacement (m)')
ax.set_xlim([0,150])
#ax.set_ylim([-1.2e-8,1e-8])
ax.legend()
plt.show()

# %%
# Compute FFTs
low_pass = 0             # [Hz] ; low frequency cutoff
high_pass = 1000*10**3    # [Hz] ; high frequency cutoff\
dt = 10**-7              # [seconds] ; sample period / time between samples
fft_units = 1000

from ae_measure2 import fft

# %%
side_upper_2
# Out:
# 0       0.000000e+00
# 1       0.000000e+00
# 2       0.000000e+00
# 3       0.000000e+00
# 4       0.000000e+00
#             ...
# 5558   -3.141080e-09
# 5559   -3.061180e-09
# 5560   -2.990270e-09
# 5561   -2.928010e-09
# 5562   -2.873740e-09
# Name: side_upper_sensor_2, Length: 5563, dtype: float64

# %%
w,z = fft(dt, wave, low_pass, high_pass)
